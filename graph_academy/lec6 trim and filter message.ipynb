# %%
from tkinter import Listbox

from mlflow_learn.lec01 import total

1+1
# Out:
# 2

# %%
# method 1
# delete the message
from typing import List

from langchain_core.messages import RemoveMessage
class MessageState:
    messages : List[str]
def filter_message(state: MessageState):
    delete_message = [RemoveMessage(id = m.id) for m in state['messages'][:-2]]
    return {'messages': delete_message}


# for m in messages：
#   m.pretty_print()

# %%
from langchain_core.messages import trim_messages
def chat_model_node(state:MessageState):
    messages = trim_messages(
        state['messages'],
        max_tokens = 100,
        strategy = 'last',
        token_counter = '',
        allow_partial = True
    )

# %%
# summary
